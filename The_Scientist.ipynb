# %% [markdown]
# ## Music Representation

# %%
# %matplotlib inline
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact

import sys
sys.path.append("../common")
from util import *
#import fmp
print('runs!')
# Out:
# runs!

# %%
plt.rcParams['figure.figsize'] = (12, 4)

# %% [markdown]
# ## Exercise 1
#
# Below is a video of Lang Lang, world famous concert pianist, playing Frederic Chopin's "Minute Waltz".
#
# The sheet music for this piece is readily available online - look it up!
#
# Questions:
# 1. How long is Lang Lang's rendition of this piece (approximately, in seconds)?
# - How many measures are there in the score?
# - How many measures are actually played in this recording? [hint, there is a repeated section]

# %%
ipd.YouTubeVideo('hKILwVH_MdM')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/hKILwVH_MdM"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ipd.YouTubeVideo('hKILwVH_MdM')

# %% [markdown]
# # Answers:

# %%
print("1)100 seconds")
print("2)125 measures")
print("3)140 measures")
# Out:
# 1)100 seconds
# 2)125 measures
# 3)140 measures

# %% [markdown]
# ##### Exercise 2
#
# Using the same score as in Exercise 1, write out what the Standard MIDI File (SMF) representation would look like for measure 5 of the Chopin Waltz.
#
# - Assume a "ticks per quarter" value of 120.
# - Remember that each midi event's tick value is a delta tick from the previous event.
# - Assign channel 1 to the left hand and channel 2 to the right hand.
# - Use note velocity = 60 for the beginning, but note that there is a slight crescendo at the end of the bar.
# - Create your answer as a python array of events, where each event is a tuple of the format:
#     `(<delta-tick>, <event-type>, <channel>, <pitch>, <velocity>)`
# - It should look a bit like [_Fig 1.13b_](data/midi_table.png) of the text.
#
# The first event is created for you as an example.

# %%
# Out:
# 13

# %%
scientist_sequence = np.array([
#1 A3 on
(0, 'note_on', 2, 69, 60, 0),
#B3 on
(0, 'note_on', 2, 59, 60, 0),
#D4 on
(0, 'note_on', 2, 62, 60 , 0),
#F4 on
(0, 'note_on', 2, 65, 60, 0),
#D4 on
(0, 'note_on', 2, 69, 60, 0),
#1 A3 off
(45, 'note_off', 2, 69, 60, 0), 
#B3 off
(0, 'note_off', 2, 59, 60, 0),
#D4 off
(0, 'note_off', 2, 62, 60 , 0),
#F4 off
(0, 'note_off', 2, 65, 60, 0),
#D4 off
(0, 'note_off', 2, 69, 60, 0),
    
#1 D3 on
(0, 'note_on', 2, 50, 60, 0),    

#1 D3 off
(60, 'note_off', 2, 50, 60, 0), 
    
#1 A3 on
(0, 'note_on', 2, 69, 60, 0),
#B3 on
(0, 'note_on', 2, 59, 60, 0),
#D4 on
(0, 'note_on', 2, 62, 60 , 0),
#F4 on
(0, 'note_on', 2, 65, 60, 0),
#D4 on
(0, 'note_on', 2, 69, 60, 0),
#1 A3 off
(45, 'note_off', 2, 69, 60, 0),  
#B3 off
(0, 'note_off', 2, 59, 60, 0),
#D4 off
(0, 'note_off', 2, 62, 60 , 0),
#F4 off
(0, 'note_off', 2, 65, 60, 0),
#D4 off
(0, 'note_off', 2, 69, 60, 0),
    
#1 D3 on
(0, 'note_on', 2, 50, 60, 0),    

#1 D3 off
(60, 'note_off', 2, 50, 60, 0), 

#1 A3 on
(0, 'note_on', 2, 69, 60, 0),
#B3 on
(0, 'note_on', 2, 59, 60, 0),
#D4 on
(0, 'note_on', 2, 62, 60 , 0),
#F4 on
(0, 'note_on', 2, 65, 60, 0),
#D4 on
(0, 'note_on', 2, 69, 60, 0),
#1 A3 off
(45, 'note_off', 2, 69, 60, 0), 
#B3 off
(0, 'note_off', 2, 59, 60, 0),
#D4 off
(0, 'note_off', 2, 62, 60 , 0),
#F4 off
(0, 'note_off', 2, 65, 60, 0),
#D4 off
(0, 'note_off', 2, 69, 60, 0),
    
#1 D3 on
(0, 'note_on', 2, 50, 60, 0),    

#1 D3 off
(60, 'note_off', 2, 50, 60, 0), 
    
#1 A3 on
(0, 'note_on', 2, 69, 60, 0),
#B3 on
(0, 'note_on', 2, 59, 60, 0),
#D4 on
(0, 'note_on', 2, 62, 60 , 0),
#F4 on
(0, 'note_on', 2, 65, 60, 0),
#D4 on
(0, 'note_on', 2, 69, 60, 0),
#1 A3 off
(45, 'note_off', 2, 69, 60, 0),  
#B3 off
(0, 'note_off', 2, 59, 60, 0),
#D4 off
(0, 'note_off', 2, 62, 60 , 0),
#F4 off
(0, 'note_off', 2, 65, 60, 0),
#D4 off
(0, 'note_off', 2, 69, 60, 0),
    
#1 D3 on
(0, 'note_on', 2, 50, 60, 0),    

#1 D3 off
(60, 'note_off', 2, 50, 60, 0),
    
###########Takt 2
    
#1 B3b on
(0, 'note_on', 2, 58, 60, 0),
    
#G3b on
(0, 'note_on', 2, 54, 60, 0),
#B3 on
(0, 'note_on', 2, 59, 60, 0),
#D4 on
(0, 'note_on', 2, 62, 60, 0),
    
#1 B3 off
(45, 'note_off', 2, 58, 60, 0),
#G3b off
(0, 'note_off', 2, 54, 60, 0),
#B3 off
(0, 'note_off', 2, 59, 60, 0),
#D4 off
(0, 'note_off', 2, 62, 60, 0),

#1 D3 on
(0, 'note_on', 2, 50, 60, 0),    

#1 D3 off
(60, 'note_off', 2, 50, 60, 0),

#1 B3b on
(0, 'note_on', 2, 58, 60, 0),
    
#G3b on
(0, 'note_on', 2, 54, 60, 0),
#B3 on
(0, 'note_on', 2, 59, 60, 0),
#D4 on
(0, 'note_on', 2, 62, 60, 0),
    
#1 B3 off
(45, 'note_off', 2, 58, 60, 0),
#G3b off
(0, 'note_off', 2, 54, 60, 0),
#B3 off
(0, 'note_off', 2, 59, 60, 0),
#D4 off
(0, 'note_off', 2, 62, 60, 0),

#1 D3 on
(0, 'note_on', 2, 50, 60, 0),    

#1 D3 off
(60, 'note_off', 2, 50, 60, 0)
    


])

# %% [markdown]
# ## Exercise 3
#
# 1. Write a python function that returns the frequency (in Hertz) of a given MIDI pitch, assuming equal tempered tuning. Test it out with `p = 69` (answer should be 440.0) and an octave lower.
#
# - Write a python function that returns the midi-pitch from any frequency (also with equal tempered tuning). The midi-pitch value should be a floating-point value. Do not round it to the nearest integer.

# %%
import math
def pitch_to_freq(p):
    f=2**((p-69)/12)*440
    return f
def freq_to_pitch(f):
    p=12*math.log2(f/440)+69
    return p

# %%
type(pitch_to_freq(69))
# Out:
# float

# %% [markdown]
# ## Exercise 4
#
# Write a python function that takes as input a midi pitch (integer) and returns its _Scientific Pitch Notation_ name as a string. For example, `69` should return the string `"A4"`.
#
# Next write a function that prints the SPN note names and frequencies of the C major scale, starting at C3 and ending at C4.

# %%
def pitch_to_spn(s) :
    octave_num = s // 12 - 1
    pitch_class_num = s%12
    
    # choosing to implement accidentals as sharps - I'm not sure if there's a convention?
    pitch_class_dict = {
        0: "C",
        1: "C#",
        2: "D",
        3: "D#",
        4: "E",
        5: "F",
        6: "F#",
        7: "G",
        8: "G#",
        9: "A",
        10: "A#",
        11: "B"
    }
    
    pitch_class = pitch_class_dict.get(pitch_class_num)
    
    name = pitch_class+str(octave_num)
    return name

print(pitch_to_spn(51))

def print_c_major() :
    for p in [48, 50, 52, 53, 55, 57, 59, 60]:
        print("SPN: "+str(pitch_to_spn(p))+", Freq: "+str(pitch_to_freq(p)))
    

print_c_major()
# Out:
# D#3
# SPN: C3, Freq: 130.8127826502993
# SPN: D3, Freq: 146.8323839587038
# SPN: E3, Freq: 164.81377845643496
# SPN: F3, Freq: 174.61411571650194
# SPN: G3, Freq: 195.99771799087463
# SPN: A3, Freq: 220.0
# SPN: B3, Freq: 246.94165062806206
# SPN: C4, Freq: 261.6255653005986

# %% [markdown]
# ## Exercise 5
#
# Write a python function that calculates the frequencies of the first N harmonics of a given midi note. For each harmonic, it should print:
# - the frequency
# - the nearest equal-tempered note for that frequency
# - the delta between those two frequencies, as measured cents (there are 100 cents in one semitone).

# %%
def print_harmonic_intontations(pitch, num_h) :
    pass

# %% [markdown]
# ## Exercise 7
#
# Write code to synthesize a tone using additive synthesis, sampled at 44,100 Hz.
#
# The inputs to your function should be:
# - the fundamental frequency (in Hz)
# - the duration in seconds
# - a list of partials. Each partial is a list of two numbers:
#   - a partial number (ie, 1 for the fundamental, 2 for the 2nd harmonic, etc...)
#   - an amplitude for that partial ($0 < a \le 1$)
#
# Your code should create the appropriate sinusoid wave for each partial in the list, add them all together, and return the result.

# %%
def make_tone(f0, dur, partials):
    fs=44100
    t=np.arange(0, dur*fs)
    for j in range(len(partials)):
        part= []
        for i in range(len(t)): 
            part.append(partials[j][1]*math.sin(2*math.pi*partials[j][0]*f0*t[i]/fs))
        if j==0:
            out_t=part
        else:
            out_t=np.add(part,out_t)
    return out_t

# %% [markdown]
# For each of `partials0`, `partials1`, and `partials2` below:
#
# - Synthesize a 3 second tone
# - Listen to the tone
# - Plot the first 1000 samples of the tone
# - Describe briefly what each one sounds like.
#
# Why does `partials2` sound different from the first two? It's also fun to run the code for `partials2` a bunch of times to hear the different versions caused by the random variable.

# %%
partials0 =  [(n, 1./n) for n in range(1,20)]
partials1 =  [(n*2-1, 1./(n*2-1) ) for n in range(1,10)]
partials2 =  [(n + np.random.random(), 1./(n)) for n in range(1,20)]

# %%
# Audio, Plots, Descriptions:
hey=make_tone(440, 3, partials0)
print(hey)
Audio(hey, rate=44100, norm=False)
# Out:
# [ 0.          1.0941038   1.70227823 ... -1.71945567 -1.70227823
#  -1.0941038 ]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(hey[:1000])

# %%
hey1=make_tone(440, 3, partials1)
print(hey1)
Audio(hey1, rate=44100, norm=False)
# Out:
# [ 0.          0.52589324  0.85446962 ... -0.92228176 -0.85446962
#  -0.52589324]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(hey1[:1000])

# %%
hey2=make_tone(440, 3, partials2)
print(hey2)
Audio(hey2, rate=44100, norm=False)
# Out:
# [0.         1.23447903 1.92434942 ... 0.56900649 0.76071762 0.94975851]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(hey2[:1000])

# %% [markdown]
# ## Exercise 8
#
# Write a function that synthesizes MIDI.
#
# The input to your synthesizer should be a list of events, exactly as specified in Exercise 2. Each synthesized note should use `make_tone` above with the proper duration and multiplied by a decaying envelope, similarly to what you did in lab. Remember to apply the note velocity. You will also need to pick a reasonable tempo.
#
# To test your function, use the `chopin_sequence` that you created in Exercise 2.
#
# The output should be a waveform that you can play with `Audio(...)`

# %%
def synthesize_midi(sequence, partials) :
    start_note=[0]*len(sequence)
    ticks = 0
    durs=[]
     
    for i in range(0,len(sequence)):
        ticks=ticks+int(sequence[i][0])
        if(sequence[i][1]=='note_on'):
            '''start note part'''
            start_note1=0
            for l in range(0,i):
                start_note1=start_note1+int(sequence[l][0])
               
            start_note[i]=start_note1  
            '''start note part'''
            for n in range(i+1,len(sequence)):
                dur=0
               
                if int(sequence[n][3])==int(sequence[i][3]) and sequence[n][1]=="note_off" :
                    for k in range(i,n+1):    
                        dur=dur+int(sequence[k][0])
                    sequence[i][5]=dur
                    break            
        else:
            sequence[n][5]=0
   
    samples=int(ticks/100*44100)
    aud=np.zeros(int(samples))
   
    for r in range(len(sequence)):
       
        for num, amp in partials:
            amp = amp*(int(sequence[r][4])/127)
        if sequence[r][1]=='note_on':
         
            s_n_sample=int(start_note[r]/100*44100)
            dur_sample=int(int(sequence[r][5])/100*44100)
            note=make_tone(pitch_to_freq(int(sequence[r][3])), float(float(sequence[r][5])/100), partials)
            v=np.linspace(0,-40,len(note))
            g=10**(v/20)
            note=np.multiply(g,note)
            aud[s_n_sample:s_n_sample+dur_sample]=np.add(note,aud[s_n_sample:s_n_sample+dur_sample])
    print(aud)
   
    return aud

# %%
scientist_sequence = np.array([
#D2 on
(0, 'note_on', 2, 38, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#D2 off
(0, 'note_off', 2, 38, 60, 0),
    
#########2
#B1b on
(0, 'note_on', 2, 34, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3# on
(0, 'note_on', 2, 58, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3# off
(0, 'note_off', 2, 58, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3# on
(0, 'note_on', 2, 58, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3# off
(0, 'note_off', 2, 58, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3# on
(0, 'note_on', 2, 58, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3# off
(0, 'note_off', 2, 58, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3# on
(0, 'note_on', 2, 58, 60, 0),
#1 F3 off
(30, 'note_off', 2, 53, 60, 0),
#1 A3# off
(0, 'note_off', 2, 58, 60, 0),    
    
#B1b off
(0, 'note_off', 2, 34, 60, 0),

######3
    
#C4 on
(0, 'note_on', 2, 60, 60, 0),

#C4 off
(30, 'note_off', 2, 60, 60, 0), 

#F2 on
(0, 'note_on', 2, 41, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#F2 off
(0, 'note_off', 2, 41, 60, 0),    
    
##########4
#C2 on
(0, 'note_on', 2, 36, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 G3 on
(0, 'note_on', 2, 55, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 G3 off
(0, 'note_off', 2, 55, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 G3 on
(0, 'note_on', 2, 55, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 G3 off
(0, 'note_off', 2, 55, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 G3 on
(0, 'note_on', 2, 55, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 G3 off
(0, 'note_off', 2, 55, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 G3 on
(0, 'note_on', 2, 55, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 G3 off
(0, 'note_off', 2, 55, 60, 0),    

    
#C2 off
(0, 'note_off', 2, 36, 60, 0),

    
    
    
    
    
#2rd angam
    
    
#D2 on
(0, 'note_on', 2, 38, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#D2 off
(0, 'note_off', 2, 38, 60, 0),
    
#########2
#B1b on
(0, 'note_on', 2, 34, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3# on
(0, 'note_on', 2, 58, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3# off
(0, 'note_off', 2, 58, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3# on
(0, 'note_on', 2, 58, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3# off
(0, 'note_off', 2, 58, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3# on
(0, 'note_on', 2, 58, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3# off
(0, 'note_off', 2, 58, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3# on
(0, 'note_on', 2, 58, 60, 0),
#1 F3 off
(30, 'note_off', 2, 53, 60, 0),
#1 A3# off
(0, 'note_off', 2, 58, 60, 0),    
    
#B1b off
(0, 'note_off', 2, 34, 60, 0),

######3
    
#C4 on
(0, 'note_on', 2, 60, 60, 0),

#C4 off
(30, 'note_off', 2, 60, 60, 0), 

#F2 on
(0, 'note_on', 2, 41, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 A3 on
(0, 'note_on', 2, 57, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 A3 off
(0, 'note_off', 2, 57, 60, 0),
    
#F2 off
(0, 'note_off', 2, 41, 60, 0),    
    
##########4
#C2 on
(0, 'note_on', 2, 36, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 G3 on
(0, 'note_on', 2, 55, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 G3 off
(0, 'note_off', 2, 55, 60, 0),

#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 G3 on
(0, 'note_on', 2, 55, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 G3 off
(0, 'note_off', 2, 55, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 G3 on
(0, 'note_on', 2, 55, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 G3 off
(0, 'note_off', 2, 55, 60, 0),
    
#1 F3 on
(0, 'note_on', 2, 53, 60, 0),
#1 G3 on
(0, 'note_on', 2, 55, 60, 0),
#1 F3 off
(60, 'note_off', 2, 53, 60, 0),
#1 G3 off
(0, 'note_off', 2, 55, 60, 0),    

    
#C2 off
(0, 'note_off', 2, 36, 60, 0),
    

#kuplet
#D2 on
(0, 'note_on', 2, 38, 60, 0),
#F2 on
(0, 'note_on', 2, 41, 60, 0),
#A2 on
(0, 'note_on', 2, 45, 60, 0),  
#F3 on
(0, 'note_on', 2, 53, 60, 0),
#A3 on
(0, 'note_on', 2, 57, 60, 0),
#F3 off
(180, 'note_off', 2, 53, 60, 0),
#A3 off
(0, 'note_off', 2, 57, 60, 0),
#F3 on
(0, 'note_on', 2, 53, 60, 0),
#F3 off
(30, 'note_off', 2, 53, 60, 0),
#G3 on
(0, 'note_on', 2, 55, 60, 0),
#G3 off
(30, 'note_off', 2, 55, 60, 0),
#F3 on
(0, 'note_on', 2, 53, 60, 0),
#F3 off
(30, 'note_off', 2, 53, 60, 0),

#C4 on
(0, 'note_on', 2, 60, 60, 0),
    
#D2 off
(30, 'note_off', 2, 38, 60, 0),
#F2 off
(0, 'note_off', 2, 41, 60, 0),
#A2 off
(0, 'note_off', 2, 45, 60, 0),    
#C4 off
(30, 'note_off', 2, 60, 60, 0),

#A3 on
(0, 'note_on', 2, 57, 60, 0),
#A3 off
(120, 'note_off', 2, 57, 60, 0)
])

# %%
# test it:
correct_chopin_sequence = scientist_sequence
x = synthesize_midi(correct_chopin_sequence, partials1)
Audio(x, rate=40000)
# Out:
# [ 0.          0.59247309  1.14073723 ... -0.0072307  -0.00525939
#  -0.00277176]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
